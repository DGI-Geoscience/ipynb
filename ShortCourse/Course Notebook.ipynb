# %% [markdown]
# #Statistical Analysis of Borehole data using Python
#
# ##About the data...
#
# Data is from a single borehole on an iron ore property located in Labrador NFLD. The data has been depth matched and errors have been removed. It was then matched up with client supplied core logged information (lithology and formations). All the data was then exported into a single CSV file. Null values are written as -999.
#
# It includes the following data:
#
# | Header | Parameter | Units| Description
# |------------|----------|------|------------------------------------|
# |Depth_m | Depth |  m | Depth downhole.|
# |RockType| Lithology | N/A |  Lithology classification from core log data.|
# |Formation| Formation | N/A| Formation classification from core log data. |
# |Natural Gamma_API| Natural Gamma| API| Natural Gamma from downhole log.|
# |SP_mV|Spontaneous Potential| mV| Spontaneous Potential from downhole log.|
# |SP Resistance_Ohm	| Single Point Resistance| Ohm| Single Point Resistance from downhole log.|
# |Fluid Resistivity_Ohm| Fluid Resistivity| Ohm| Fluid Resistivity from downhole log.|
# |Temperature_DegC|Temperature| Degrees Celsius| Temperature from downhole log.|
# |Res8_Ohm-m|8 Inch Resistivity|Ohm-m| Resistivity from 8 inch receiver from downhole log.|
# |Res16_Ohm-m|16 Inch Resistivity|Ohm-m| Resistivity from 16 inch receiver from downhole log.|
# |Res32_Ohm-m|32 Inch Resistivity|Ohm-m| Resistivity from 32 inch receiver from downhole log.|
# |Res64_Ohm-m|64 Inch Resistivity|Ohm-m| Resistivity from 64 inch receiver from downhole log.|
# |Near Density_gcc|Near Density| g/cc| Density from the near detector from downhole log.|
# |Far Density_gcc|Far Density | g/cc| Density from the far detector from downhole log.|
# |MS_mCGS|Magnetic Susceptibiltiy| mCGS| Magnetic Susceptibility from downhole log.|
#
# ##Lithology Dictionary
# |Code|LongName|
# |------|-----------------|
# |B_MS_SCH|Biotite Meta-Sediment Schist|
# |GF_B_MS_SCH|Graphite Biotite Meta-Sediment Schist|
# |HBG_GN|Biotite Garnet Gneiss|
# |HIF|Hematite Iron Formation|
# |HMIF|Hematite-Magnetite Iron Formation|
# |MHIF|Magnetite-Hematite Iron Formation|
# |MIF|Magnetite Iron Formation|
# |MS_B_SCH|Meta-Sediment Biotite Schist|
# |QCIF|Quartz Carbonate Iron Formation|
# |QSIF|Quartz Sulfur Iron Formation|
# |QZT|Quartz Vien|
# |QZT-MS|Quartz Vien - Meta-Sediment|
# |QZ_MS_B_CC_SCH|Quartz Meta-Sediment Biotite Carbonate Schist|
# |SIF|Sulfur Iron Formation|
#
#
#
#
#
# ##Using Python and IPython Notebook
# Python is a programming language that is used extensively in data analysis. Some other popular languages include MATLAB and R.  For the purposed of this exercise we will use Python with the SciPy package which includes *pandas* for data management and *matplotlib* for visualization. IPython is an interactive interpreter that allows you to analyze data while having your results and notes inline with the code.
#
# The code is here for reference and thus we will not be discussing what each piece does. However, if you have further questions about the code, please contact Patrick Hooker at phooker@dgigeoscience.com
#
#
# ##Import libraries
#
# To start we must initialise the worksheet and import the libraries we plan to use.

# %%
# %pylab inline
pylab.rcParams['figure.figsize'] = (12.0, 7.0)
import numpy as np
from scipy import stats
import matplotlib.pyplot as pt
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ##Import Data
#
# Using pandas, we import the data and set the first column (Depth) in the sheet as the main index.
# Then we find all the null values and set them as NaN (not a number).

# %%
data=pd.read_csv('Course_Data.csv',index_col=0)
data=data.replace(-999,np.nan)
data
# Out:
#          RockType        Formation  NaturalGamma_API    SP_mV  \
# Depth_m
# 7.8      MS_B_SCH  Menihek Fm (HW)           311.868  147.375
# 8.0      MS_B_SCH  Menihek Fm (HW)           290.243  145.375
# 8.2      MS_B_SCH  Menihek Fm (HW)           252.250  140.625
# 8.4      MS_B_SCH  Menihek Fm (HW)           193.140  135.000
# 8.6      MS_B_SCH  Menihek Fm (HW)           258.828  129.500
# 8.8      MS_B_SCH  Menihek Fm (HW)           256.501  123.750
# 9.0      MS_B_SCH  Menihek Fm (HW)           276.357  119.875
# 9.2      MS_B_SCH  Menihek Fm (HW)           281.147  120.875
# 9.4      MS_B_SCH  Menihek Fm (HW)           251.344  120.500
# 9.6      MS_B_SCH  Menihek Fm (HW)           229.587  114.125
# 9.8      MS_B_SCH  Menihek Fm (HW)           254.030  112.125
# 10.0     MS_B_SCH  Menihek Fm (HW)           211.500  117.500
# 10.2     MS_B_SCH  Menihek Fm (HW)           273.841  121.375
# 10.4     MS_B_SCH  Menihek Fm (HW)           244.035  123.375
# 10.6     MS_B_SCH  Menihek Fm (HW)           231.533  121.000
# 10.8     MS_B_SCH  Menihek Fm (HW)           283.768  115.000
# 11.0     MS_B_SCH  Menihek Fm (HW)           264.297  117.250
# 11.2     MS_B_SCH  Menihek Fm (HW)           260.771  145.125
# 11.4     MS_B_SCH  Menihek Fm (HW)           252.428  221.000
# 11.6     MS_B_SCH  Menihek Fm (HW)           280.199  301.625
# 11.8     MS_B_SCH  Menihek Fm (HW)           267.717  337.750
# 12.0     MS_B_SCH  Menihek Fm (HW)           251.459  369.250
# 12.2     MS_B_SCH  Menihek Fm (HW)           288.219  461.750
# 12.4     MS_B_SCH  Menihek Fm (HW)           272.789  632.500
# 12.6     MS_B_SCH  Menihek Fm (HW)           273.822  802.750
# 12.8     MS_B_SCH  Menihek Fm (HW)           267.759  852.125
# 13.0     MS_B_SCH  Menihek Fm (HW)           242.360  827.000
# 13.2     MS_B_SCH  Menihek Fm (HW)           200.275  857.125
# 13.4     MS_B_SCH  Menihek Fm (HW)           282.208  841.750
# 13.6     MS_B_SCH  Menihek Fm (HW)           262.968  695.750
# 13.8     MS_B_SCH  Menihek Fm (HW)           231.690  588.625
# 14.0     MS_B_SCH  Menihek Fm (HW)           170.526  574.375
# 14.2     MS_B_SCH  Menihek Fm (HW)           256.024  568.125
# 14.4     MS_B_SCH  Menihek Fm (HW)           290.802  557.875
# 14.6     MS_B_SCH  Menihek Fm (HW)           254.495  542.625
# 14.8     MS_B_SCH  Menihek Fm (HW)           265.075  524.500
# 15.0     MS_B_SCH  Menihek Fm (HW)           281.453  517.125
# 15.2     MS_B_SCH  Menihek Fm (HW)           289.105  516.625
# 15.4     MS_B_SCH  Menihek Fm (HW)           297.133  516.375
# 15.6     MS_B_SCH  Menihek Fm (HW)           239.216  517.750
# 15.8     MS_B_SCH  Menihek Fm (HW)           232.138  522.875
# 16.0     MS_B_SCH  Menihek Fm (HW)           182.268  534.500
# 16.2     MS_B_SCH  Menihek Fm (HW)           171.454  547.125
# 16.4     MS_B_SCH  Menihek Fm (HW)           248.862  560.625
# 16.6     MS_B_SCH  Menihek Fm (HW)           234.233  573.000
# 16.8     MS_B_SCH  Menihek Fm (HW)           302.633  578.750
# 17.0     MS_B_SCH  Menihek Fm (HW)           240.116  579.375
# 17.2     MS_B_SCH  Menihek Fm (HW)           262.629  578.500
# 17.4     MS_B_SCH  Menihek Fm (HW)           261.837  579.875
# 17.6     MS_B_SCH  Menihek Fm (HW)           271.121  585.125
# 17.8     MS_B_SCH  Menihek Fm (HW)           224.479  587.750
# 18.0     MS_B_SCH  Menihek Fm (HW)           224.570  582.500
# 18.2     MS_B_SCH  Menihek Fm (HW)           209.230  569.875
# 18.4     MS_B_SCH  Menihek Fm (HW)           230.607  559.125
# 18.6     MS_B_SCH  Menihek Fm (HW)           242.450  562.000
# 18.8     MS_B_SCH  Menihek Fm (HW)           325.173  574.375
# 19.0     MS_B_SCH  Menihek Fm (HW)           222.390  583.250
# 19.2     MS_B_SCH  Menihek Fm (HW)           276.294  585.500
# 19.4     MS_B_SCH  Menihek Fm (HW)           238.225  584.750
# 19.6     MS_B_SCH  Menihek Fm (HW)           246.607  579.750
#               ...              ...               ...      ...
#
#          SPResistance_Ohm  FluidResistivity_Ohm  Temperature_DegC  Res8_Ohm-m  \
# Depth_m
# 7.8                   NaN                   NaN               NaN         NaN
# 8.0                   NaN                   NaN               NaN         NaN
# 8.2                   NaN                   NaN               NaN         NaN
# 8.4                   NaN                   NaN               NaN         NaN
# 8.6                   NaN                   NaN               NaN         NaN
# 8.8                   NaN                   NaN               NaN         NaN
# 9.0                   NaN                   NaN               NaN         NaN
# 9.2                   NaN                   NaN               NaN  126190.000
# 9.4                   NaN                   NaN               NaN  124161.000
# 9.6              84930.10               145.122           4.06738  120186.000
# 9.8              83910.30               145.107           4.05371  111408.000
# 10.0             80738.30               145.099           4.04785  100325.000
# 10.2             79743.30               145.077           4.06934   95028.700
# 10.4             82904.30               145.069           4.06543   89986.600
# 10.6             83963.30               145.077           4.10547   87495.000
# 10.8             83928.60               145.069           4.08105   89964.000
# 11.0             86446.80               145.054           4.05078   93179.400
# 11.2             89393.40               141.020           4.11523  109358.000
# 11.4             91677.50               111.969           4.07324  129064.000
# 11.6             86342.80               111.548           4.05957  141387.000
# 11.8             68314.80               111.473           4.03809  145661.000
# 12.0             56407.00               111.616           4.05469  146346.000
# 12.2             55680.00               112.037           4.06055  146107.000
# 12.4             55845.70               112.405           4.05371  143314.000
# 12.6             55367.60               112.638           4.06641  106007.000
# 12.8             55280.00               113.299           4.08887   58746.000
# 13.0             50194.90               113.652           4.04297   38222.600
# 13.2             32336.30               113.742           4.09375   31171.400
# 13.4             19815.80               113.704           4.06934   26507.600
# 13.6             14966.60               113.697           4.06250   19224.400
# 13.8             13558.00               113.802           4.06543   13817.600
# 14.0             10926.10               113.967           4.04688   11313.100
# 14.2              8425.96               114.065           4.06543    8012.500
# 14.4              7232.32               114.283           4.07129    5123.830
# 14.6              5728.30               114.351           4.09277    4234.030
# 14.8              3871.95               114.568           4.06543    2747.500
# 15.0              3050.90               114.598           4.06348    1504.610
# 15.2              2524.67               114.546           4.02930    1060.800
# 15.4              1890.93               114.719           4.08496     954.640
# 15.6              1440.31               114.794           4.04980     896.397
# 15.8              1281.40               114.846           3.99609     986.500
# 16.0              1283.02               114.749           3.96777    1114.310
# 16.2              1641.40               114.967           3.95410    1418.550
# 16.4              2034.52               115.019           3.93359    1717.120
# 16.6              2443.65               115.124           3.96191    1542.460
# 16.8              2834.00               115.094           3.95215    1268.290
# 17.0              2558.17               115.027           3.97754    1167.280
# 17.2              2238.29               115.079           3.96680    1149.870
# 17.4              2229.31               111.819           3.93652    1189.290
# 17.6              2142.65               110.271           3.96289    1212.660
# 17.8              1975.10               114.027           3.91504    1190.510
# 18.0              1884.31               115.147           3.95020    1147.860
# 18.2              1863.57               115.387           3.90430    1224.670
# 18.4              1977.44               115.485           3.90137    1436.540
# 18.6              2148.69               115.680           3.89941    2072.140
# 18.8              2430.64               115.823           3.87793    3531.390
# 19.0              3071.59               115.891           3.87305    5010.840
# 19.2              4144.50               115.966           3.81348    5887.890
# 19.4              5005.12               116.018           3.86426    4693.270
# 19.6              5532.38               116.048           3.82715    2632.890
#                       ...                   ...               ...         ...
#
#          Res16_Ohm-m  Res32_Ohm-m  Res64_Ohm-m  NearDensity_gcc  \
# Depth_m
# 7.8              NaN          NaN          NaN          2.69629
# 8.0              NaN          NaN          NaN          2.71381
# 8.2              NaN          NaN          NaN          2.75687
# 8.4              NaN          NaN          NaN          2.76645
# 8.6              NaN          NaN    539295.00          2.51283
# 8.8              NaN          NaN    270758.00          2.60199
# 9.0              NaN    207332.00    121757.00          2.77611
# 9.2        169288.00    217294.00    391148.00          2.75093
# 9.4        174103.00    221426.00    554147.00          2.73387
# 9.6        177179.00    212896.00    554611.00          2.74454
# 9.8        170039.00    216261.00    525789.00          2.69482
# 10.0       169650.00    209452.00    457038.00          2.70498
# 10.2       166153.00    194409.00    376383.00          2.75544
# 10.4       159030.00    197809.00    387259.00          2.81465
# 10.6       165361.00    204181.00    189362.00          2.74176
# 10.8       172917.00    228695.00     -9531.57          2.75390
# 11.0       188454.00    294686.00    -15916.30          2.76433
# 11.2       228205.00    349053.00    -15944.60          2.76357
# 11.4       266733.00    364669.00    -15847.00          2.76741
# 11.6       285075.00    275400.00    -15825.20          2.73730
# 11.8       290926.00    298152.00    -14855.50          2.81754
# 12.0       291824.00    305501.00    -11529.20          2.39574
# 12.2       290941.00    267995.00     41280.80          2.62479
# 12.4       258568.00    220778.00     38520.70          2.82209
# 12.6       156450.00    120218.00     36694.40          2.75330
# 12.8        87884.70     80069.10     96147.20          2.77385
# 13.0        62540.30     70832.10     94520.10          2.75902
# 13.2        56295.00     52974.10     71895.00          2.72480
# 13.4        42749.20     33258.40     56614.00          2.76902
# 13.6        28266.40     24054.60     37683.90          2.79503
# 13.8        21748.20     18764.90     28737.20          2.74557
# 14.0        17273.30     12718.80     22237.10          2.66177
# 14.2        11541.90     10048.30     13635.90          2.52412
# 14.4         8760.18      8028.87      8454.39          2.65178
# 14.6         6688.04      4994.88      6786.36          2.71599
# 14.8         3962.88      3208.42      6059.38          2.66553
# 15.0         2411.23      2714.17      5870.65          2.69528
# 15.2         1942.59      2489.83      6303.79          2.73169
# 15.4         1712.66      2365.37      6468.85          2.70335
# 15.6         1625.91      2446.11      6574.31          2.70168
# 15.8         1748.02      2539.55      6452.38          2.61146
# 16.0         1842.54      2648.37      6385.13          2.68316
# 16.2         1950.10      2612.04      6377.10          2.71864
# 16.4         2009.70      2588.66      6417.40          2.73410
# 16.6         1990.80      2626.13      6408.30          2.67107
# 16.8         1945.43      2619.02      6324.02          2.80076
# 17.0         1893.09      2600.84      6314.08          2.80864
# 17.2         1864.07      2582.86      6290.72          2.73332
# 17.4         1878.98      2564.70      6338.55          2.80656
# 17.6         1898.73      2562.03      6458.20          2.74140
# 17.8         1916.74      2562.91      6648.11          2.73274
# 18.0         1912.23      2600.73      6959.87          2.76329
# 18.2         1969.24      2735.61      7187.56          2.74231
# 18.4         2106.34      2875.83      7246.87          2.77026
# 18.6         2420.65      2941.84      7027.56          2.77562
# 18.8         3332.59      2985.93      6690.69          2.76481
# 19.0         4835.10      2951.30      6602.23          2.77959
# 19.2         5342.54      2758.99      6650.50          2.78545
# 19.4         4033.87      2641.49      6757.33          2.78675
# 19.6         2767.48      2701.54      6685.90          2.80918
#                  ...          ...          ...              ...
#
#          FarDensity_gcc   MS_mCGS
# Depth_m
# 7.8             2.68244  0.201979
# 8.0             2.71279  0.232668
# 8.2             2.72810  0.230927
# 8.4             2.65252  0.276198
# 8.6             2.62399  0.225485
# 8.8             2.58747  0.261616
# 9.0             2.70609  0.283381
# 9.2             2.67952  0.350417
# 9.4             2.69965  0.377406
# 9.6             2.69498  0.276198
# 9.8             2.72077  0.216344
# 10.0            2.69938  0.270757
# 10.2            2.79185  0.240068
# 10.4            2.77464  0.303187
# 10.6            2.79245  0.312328
# 10.8            2.77195  0.352159
# 11.0            2.73883  0.316028
# 11.2            2.80691  0.330393
# 11.4            2.89286  0.287081
# 11.6            2.82043  0.209162
# 11.8            2.73630  0.250733
# 12.0            2.52663  0.221785
# 12.2            2.70501  0.243551
# 12.4            2.87469  0.267057
# 12.6            2.72598  0.245292
# 12.8            2.79986  0.256174
# 13.0            2.83277  0.230927
# 13.2            2.81032  0.281640
# 13.4            2.86789  0.209162
# 13.6            2.76164  0.270757
# 13.8            2.82214  0.274239
# 14.0            2.71445  0.276198
# 14.2            2.68358  0.234627
# 14.4            2.79058  0.216344
# 14.6            2.76237  0.221785
# 14.8            2.75648  0.225485
# 15.0            2.75981  0.209162
# 15.2            2.71096  0.220044
# 15.4            2.78226  0.198279
# 15.6            2.84171  0.185655
# 15.8            2.72777  0.254433
# 16.0            2.71738  0.368482
# 16.2            2.72796  0.191097
# 16.4            2.77749  0.227227
# 16.6            2.81055  0.256174
# 16.8            2.78818  0.299705
# 17.0            2.82929  0.321470
# 17.2            2.86416  0.267057
# 17.4            2.78133  0.288822
# 17.6            2.83666  0.277939
# 17.8            2.77894  0.281640
# 18.0            2.81256  0.294263
# 18.2            2.83246  0.270757
# 18.4            2.76696  0.269016
# 18.6            2.81678  0.258133
# 18.8            2.80356  0.210903
# 19.0            2.85896  0.288822
# 19.2            2.85236  0.265316
# 19.4            2.81792  0.292522
# 19.6            2.80764  0.323211
#                     ...       ...
#
# [1202 rows x 14 columns]

# %% [markdown]
# ##Basic Descriptive Statistics
#
# ####Measure of Central Tendency (Averages)
# - Mean
#   * Sum of data points divided by the number of data points
#   * Most popular measure of average
#   * Susceptible to outliers and bad data
# - Median
#   * The middle value in an ordered data set
#   * Not susceptible to outliers and bad data
# - Mode
#   * The most frequently occurring value in a data set
#   * Does not give indication to shape of distribution
#
# ####Measures of Spread, Variability and Shape
# - Standard Deviation
#   * Measure of the dispersion from the mean
# - Variance
#   * The square of the standard deviation
# - Range
#   * The difference between the minimum and maximum values in a data set
# - Quartiles and Inter-quartile range
#   * 25th and 75th percentile are defined as the 1st and 3rd quartile; the 2nd quartile (50th percentile) is the median
#   * Inter-quartile range is the difference between the 1st and 3rd quartiles.
#
# The data can now be quickly summarized using the describe() function.
#
# Highlight and drag the table to scroll horizontally.

# %%
data.describe()
# Out:
#        NaturalGamma_API        SP_mV  SPResistance_Ohm  FluidResistivity_Ohm  \
# count       1173.000000  1197.000000       1185.000000           1193.000000
# mean         118.306628   624.380952       4377.725089             94.375154
# std          121.521273   101.746861       9255.083967             33.629276
# min            0.000000   112.125000         21.652900             49.517600
# 25%            3.569130   587.125000        990.021000             55.152000
# 50%           56.837000   640.000000       2778.800000            111.969000
# 75%          231.736000   697.000000       5448.740000            125.552000
# max          636.726000   857.125000      91677.500000            145.122000
#
#        Temperature_DegC     Res8_Ohm-m    Res16_Ohm-m    Res32_Ohm-m  \
# count       1193.000000    1195.000000    1195.000000    1196.000000
# mean           2.960748    7439.416873   11811.438741   10263.185154
# std            0.355316   15192.706016   27636.722849   31548.503845
# min            2.591800     231.741000     469.357000     818.374000
# 25%            2.760740     869.257500    1053.795000    1509.235000
# 50%            2.794920    3506.380000    3809.430000    2596.305000
# 75%            3.031250    9870.610000   12200.900000    5638.502500
# max            4.115230  146346.000000  291824.000000  364669.000000
#
#          Res64_Ohm-m  NearDensity_gcc  FarDensity_gcc      MS_mCGS
# count    1196.000000      1167.000000     1167.000000  1174.000000
# mean    15106.874532         3.044097        3.053332     8.913572
# std     41853.955566         0.445379        0.356299    16.462624
# min    -15944.600000         2.325180        2.526630     0.116877
# 25%      3255.907500         2.707045        2.775385     0.165849
# 50%      4916.525000         2.805150        2.865240     0.260745
# 75%      8825.622500         3.423805        3.386885     5.099245
# max    554611.000000         4.390060        3.977050    62.544900
#
# [8 rows x 12 columns]

# %% [markdown]
# ***
# #Question 1
#
# Examining the table above, there is at least one parameter that may contain an error. What is it and why?
#
#
#
#
#
#
#
#
#
#
# ***

# %% [markdown]
# ##Visualization
#
# ###Histograms
#
# Data is distributed into bins that are defined by either a total number of bins or specific values. The data is plotted using bar graphs with the x-axis representing the value and the y-axis representing the frequency.  These graphs are useful for identifying anomalies in the data such as skewed distributions or many values occurring within a single bin.
#
# It should be noted that some parameters, especially magnetic and electrical, should be plotted using a log scale.

# %%
pt.subplot(1,2,1)
ax=data.SP_mV.hist(bins=50)
ax.set_xscale('log')
ax.set_ylabel('Frequency')
ax.set_xlabel('SP')

pt.subplot(1,2,2)
ax=data.SPResistance_Ohm.hist(bins=50)
ax.set_ylabel('Frequency')
ax.set_xlabel('SP Resistance')

# %%
pt.subplot(1,2,1)
ax=data.FluidResistivity_Ohm.hist(bins=50)

ax.set_ylabel('Frequency')
ax.set_xlabel('Fluid Resistivity')

pt.subplot(1,2,2)
ax=data.Temperature_DegC.hist(bins=50)
ax.set_ylabel('Frequency')
ax.set_xlabel('Temperature')

# %%
pt.subplot(1,2,1)
ax=data['Res8_Ohm-m'].hist(bins=np.logspace(np.min(np.log10(data['Res8_Ohm-m'])),np.max(np.log10(data['Res8_Ohm-m']))))
ax.set_xscale('log')
ax.set_ylabel('Frequency')
ax.set_xlabel('8 Inch Resistivity')

pt.subplot(1,2,2)
ax=data['Res16_Ohm-m'].hist(bins=np.logspace(np.min(np.log10(data['Res16_Ohm-m'])),np.max(np.log10(data['Res16_Ohm-m']))))
ax.set_xscale('log')
ax.set_ylabel('Frequency')
ax.set_xlabel('16 Inch Resistivity')

# %%
pt.subplot(1,2,1);
ax=data['Res32_Ohm-m'].hist(bins=np.logspace(np.min(np.log10(data['Res32_Ohm-m'])),np.max(np.log10(data['Res32_Ohm-m']))));
ax.set_xscale('log');
ax.set_ylabel('Frequency');
ax.set_xlabel('64 Inch Resistivity');

pt.subplot(1,2,2);
ax=data['Res64_Ohm-m'].hist(bins=np.logspace(np.min(np.log10(data['Res64_Ohm-m'])),np.max(np.log10(data['Res64_Ohm-m']))));
ax.set_xscale('log');
ax.set_ylabel('Frequency');
ax.set_xlabel('64 Inch Resistivity');

# %%
pt.subplot(1,2,1);
ax=data.NaturalGamma_API.hist(bins=50);

ax.set_ylabel('Frequency');
ax.set_xlabel('Natural Gamma');

pt.subplot(1,2,2);
ax=data.MS_mCGS.hist(bins=np.logspace(np.min(np.log10(data['MS_mCGS'])),np.max(np.log10(data['MS_mCGS']))));
ax.set_xscale('log');
ax.set_ylabel('Frequency');
ax.set_xlabel('Magnetic Susceptibility');

# %%
pt.subplot(1,2,1);
ax=data.NearDensity_gcc.hist(bins=50);

ax.set_ylabel('Frequency');
ax.set_xlabel('Near Density');

pt.subplot(1,2,2);
ax=data.FarDensity_gcc.hist(bins=50);
ax.set_ylabel('Frequency');
ax.set_xlabel('Far Density');

# %% [markdown]
# ***
# # Question 2
# The distributions shown above generally do not show a normal distribution. Explain why this is the case.
#
#
#
#
#
#
# ***

# %% [markdown]
# ###Scatter (Cross) Plots
#
# The scatter plots will be coloured coded by RockType. For simplicity, we'll show only the following graphs:
#
# - 16 Inch Resistivity vs. Magnetic Susceptibility
# - 16 Inch Resistivity vs. Near Density
# - Magnetic Susceptibility vs. Near Density
# - Natural Gamma vs. Near Density.
#
# First we define the unique RockType and assign each a standard color.

# %%
uniqueGroups=data.RockType.unique();
uniqueGroups.sort()
nColor=len(uniqueGroups)
cmap = matplotlib.cm.get_cmap('jet',nColor);
colors=cmap(np.arange(nColor))

# %% [markdown]
# The code below cycles through each rock type from the RockType column finds the rows where that rock type exists and generates a new data table for it.
#
# The specified columns are then plotted against each other.

# %%
for i,co in zip(uniqueGroups,colors) :
    dataGroup=data[data.RockType.str.contains(i)]
    ax=pt.plot(dataGroup['Res16_Ohm-m'],dataGroup['MS_mCGS'],color=co,label=i,
               linestyle='None', marker='o');
pt.legend();
ax=pt.gca();
ax.set_xscale('log');
ax.set_yscale('log');
ax.set_ylabel('Magnetic Susceptibility');
ax.set_xlabel('Resistivity');

# %%
for i,co in zip(uniqueGroups,colors) :
    dataGroup=data[data.RockType.str.contains(i)]
    ax=pt.plot(dataGroup['Res16_Ohm-m'],dataGroup['NearDensity_gcc'],color=co,label=i,
               linestyle='None', marker='o');
pt.legend();
ax=pt.gca();
ax.set_xscale('log');
ax.set_ylabel('Density');
ax.set_xlabel('Resistivity');

# %%
for i,co in zip(uniqueGroups,colors) :
    dataGroup=data[data.RockType.str.contains(i)]
    ax=pt.plot(dataGroup['MS_mCGS'],dataGroup['NearDensity_gcc'],color=co,label=i,
               linestyle='None', marker='o');
pt.legend();
ax=pt.gca();
ax.set_xscale('log');
ax.set_ylabel('Density');
ax.set_xlabel('Magnetic Susceptibility');

# %%
for i,co in zip(uniqueGroups,colors) :
    dataGroup=data[data.RockType.str.contains(i)]
    ax=pt.plot(dataGroup['NaturalGamma_API'],dataGroup['NearDensity_gcc'],color=co,label=i,
               linestyle='None', marker='o');
pt.legend();
ax=pt.gca();
ax.set_ylabel('Density');
ax.set_xlabel('Natural Gamma');

# %% [markdown]
# ###Box and Whisker Plots
#
# Box and Whisker plots (hereafter referred to as boxplots) are used to compare grouped data for a single variable.  They are useful because they provide a lot of information in a compact, visual manner. Boxplots can be viewed horizontally or vertically, below is an example of a horizontal boxplot, showing how it compares to a normal distribution.  Q1 and Q3 refer to the first and third quartiles represented by the left and right edges of the box respectively (in a vertical boxplot it is represented by the bottom and top). The median is represented by the solid line in the center of the box. The whiskers are generally represented as being 1.5 times the inter-quartile range (IQR) and then added to or subtracted from Q1 and Q3. Points that fall outside of these ranges are classifed as outliers and are represented by points ('+' symbol in the case of the plots shown below).
#
# ![](boxplot_example.png?raw=true,"Boxplot Example")

# %%
ax=data.boxplot(column='NearDensity_gcc',by='RockType',vert=True);
pt.xticks(rotation=70);

# %%
ax=data.boxplot(column='MS_mCGS',by='RockType',vert=True);
ax.set_yscale('log')
pt.xticks(rotation=70);

# %%
ax=data.boxplot(column='Res16_Ohm-m',by='RockType',vert=True);
ax.set_yscale('log')
pt.xticks(rotation=70);

# %%
ax=data.boxplot(column='NaturalGamma_API',by='RockType',vert=True);
pt.xticks(rotation=70);

# %% [markdown]
# ***
# #Question 3
# From the scatter and boxplots, there are three to four different groupings that become apparent.  Describe how those groups relate to each physical parameter and rock type.
#
#
#
#
# ***

# %% [markdown]
# ***
# #Question 4
# Based on the conclusions above, what further geophysical surveys (airborne, ground, borehole) would you perform to further help understand the deposit?
#
#
#
# ***
